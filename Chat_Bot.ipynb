# %%
import google.generativeai as genai
key = ("AIzaSyABxunNtJJFTy1xVrO8O_h0pDY-6zbUDF0")
genai.configure(api_key=key)
model = genai.GenerativeModel("gemini-2.5-flash")
while True:
    user = input("Enter what you want to search or type exit to close:")
    if user.lower() == "exit":
        print("bye bye")
        break
    response = model.generate_content(user)
    print ("BOT: ", response.text)
# Out:
# Enter what you want to search or type exit to close: hello
# BOT:  Hello! How can I help you today?
# Enter what you want to search or type exit to close: exit
# bye bye
